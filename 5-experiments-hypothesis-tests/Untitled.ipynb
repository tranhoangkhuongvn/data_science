# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

#Question:
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
data=pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv',index_col=0)
data.tail()
# Out:
#         TV  radio  newspaper  sales
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X=data-data.mean()
X/len(X)-1
#Question: X.T.dot(X)
# Out:
#            TV    radio  newspaper     sales
# 1   -0.584712 -0.92732   -0.80677 -0.959612
# 2   -1.512712 -0.91982   -0.92727 -1.018112
# 3   -1.649212 -0.88682   -0.80627 -1.023613
# 4   -0.977712 -0.90982   -0.86027 -0.977612
# 5   -0.831212 -1.06232   -0.86077 -1.005613
# 6   -1.691712 -0.87182   -0.77777 -1.034112
# 7   -1.447712 -0.95232   -1.03527 -1.011113
# 8   -1.134212 -1.01832   -1.09477 -1.004112
# 9   -1.692213 -1.10582   -1.14777 -1.046113
# 10  -0.736212 -1.10332   -1.04677 -1.017113
# 11  -1.404713 -1.08732   -1.03177 -1.027113
# 12  -0.661712 -0.99632   -1.13277 -0.983113
# 13  -1.616213 -0.94082   -0.82327 -1.024112
# 14  -1.247713 -1.07832   -1.11677 -1.021613
# 15  -0.714712 -0.95182   -0.92277 -0.975113
# 16  -0.758212 -0.87782   -0.88827 -0.958113
# 17  -1.396212 -0.93332   -0.58277 -1.007613
# 18  -0.328213 -0.91832   -0.87377 -0.948113
# 19  -1.389212 -1.01382   -1.06127 -1.013613
# 20  -0.998712 -0.99682   -1.05727 -0.997113
# 21  -0.643212 -0.97782   -0.88577 -0.980113
# 22  -0.548212 -1.09082   -1.03527 -1.007613
# 23  -1.669212 -1.03682   -0.90477 -1.042112
# 24  -0.593712 -1.03182   -1.02177 -0.992613
# 25  -1.423712 -1.05332   -1.06127 -1.021613
# 26  -0.420713 -1.09882   -1.05527 -1.010112
# 27  -1.020712 -0.96982   -1.08977 -0.995113
# 28  -0.534712 -1.03282   -1.03827 -0.990613
# 29  -0.491212 -0.98082   -1.03827 -0.975612
# 30  -1.382213 -1.03632   -0.94877 -1.017613
# ..        ...      ...        ...       ...
# 171 -1.485212 -1.05832   -1.06077 -1.028112
# 172 -0.912712 -1.01182   -0.91577 -0.997613
# 173 -1.637212 -1.01582   -1.06777 -1.032112
# 174 -0.893212 -1.08082   -1.08877 -1.011613
# 175 -0.623212 -1.09932   -1.08727 -1.012612
# 176 -0.350713 -0.87182   -0.94377 -0.935113
# 177 -0.493212 -0.96532   -1.05127 -0.969113
# 178 -0.884213 -1.07732   -0.97677 -1.011613
# 179 -0.351712 -1.10482   -1.03427 -1.011113
# 180 -0.907212 -1.06632   -1.06477 -1.007113
# 181 -0.952213 -1.10332   -1.11127 -1.017613
# 182 -0.642713 -1.08932   -1.01577 -1.009113
# 183 -1.454212 -1.08782   -1.00427 -1.026612
# 184 -0.297212 -0.90132   -0.79377 -0.939113
# 185 -0.466212 -1.00982   -1.00277 -0.982113
# 186 -0.710212 -0.89082   -1.05477 -0.957113
# 187 -1.037713 -1.10582   -1.01977 -1.018612
# 188 -0.779713 -0.97282   -1.06177 -0.983613
# 189 -0.305212 -1.04682   -1.13427 -0.990613
# 190 -1.641713 -1.05582   -1.03577 -1.036612
# 191 -1.537713 -0.91082   -1.12377 -1.016112
# 192 -1.357712 -1.06232   -1.12277 -1.020612
# 193 -1.649212 -1.09582   -0.99477 -1.040612
# 194 -0.901212 -0.90632   -1.13477 -0.972113
# 195 -0.986712 -0.93832   -1.12277 -0.983613
# 196 -1.544212 -1.09782   -1.08377 -1.032112
# 197 -1.264212 -1.09182   -1.11227 -1.021613
# 198 -0.850212 -1.06982   -1.12077 -1.006112
# 199 -0.317212 -0.90632   -0.82177 -0.942612
# 200 -0.574712 -1.07332   -1.10927 -1.003113
#
# [200 rows x 4 columns]

# %%
data.cov()
# Out:
#                     TV       radio   newspaper       sales
# TV         7370.949893   69.862492  105.919452  350.390195
# radio        69.862492  220.427743  114.496979   44.635688
# newspaper   105.919452  114.496979  474.308326   25.941392
# sales       350.390195   44.635688   25.941392   27.221853

# %%
data.cov()/data.std()
# Out:
#                   TV      radio  newspaper      sales
# TV         85.854236   4.705556   4.863460  67.157281
# radio       0.813734  14.846809   5.257311   8.555067
# newspaper   1.233713   7.711891  21.778621   4.972038
# sales       4.081222   3.006416   1.191140   5.217457

# %%
data.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row0_col0 {
#             background-color:  #023858;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row0_col3 {
#             background-color:  #1278b4;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row1_col1 {
#             background-color:  #023858;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row1_col2 {
#             background-color:  #bbc7e0;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row1_col3 {
#             background-color:  #88b1d4;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row2_col0 {
#             background-color:  #fff7fb;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row2_col1 {
#             background-color:  #b9c6e0;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row2_col2 {
#             background-color:  #023858;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row2_col3 {
#             background-color:  #fff7fb;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row3_col0 {
#             background-color:  #056caa;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row3_col1 {
#             background-color:  #5a9ec9;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row3_col2 {
#             background-color:  #e0dded;
#         }    #T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row3_col3 {
#             background-color:  #023858;
#         }</style>
# <table id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >TV</th>
#         <th class="col_heading level0 col1" >radio</th>
#         <th class="col_heading level0 col2" >newspaper</th>
#         <th class="col_heading level0 col3" >sales</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1level0_row0" class="row_heading level0 row0" >TV</th>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row0_col0" class="data row0 col0" >1</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row0_col1" class="data row0 col1" >0.0548087</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row0_col2" class="data row0 col2" >0.0566479</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row0_col3" class="data row0 col3" >0.782224</td>
#     </tr>    <tr>
#         <th id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1level0_row1" class="row_heading level0 row1" >radio</th>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row1_col0" class="data row1 col0" >0.0548087</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row1_col1" class="data row1 col1" >1</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row1_col2" class="data row1 col2" >0.354104</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row1_col3" class="data row1 col3" >0.576223</td>
#     </tr>    <tr>
#         <th id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1level0_row2" class="row_heading level0 row2" >newspaper</th>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row2_col0" class="data row2 col0" >0.0566479</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row2_col1" class="data row2 col1" >0.354104</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row2_col2" class="data row2 col2" >1</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row2_col3" class="data row2 col3" >0.228299</td>
#     </tr>    <tr>
#         <th id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1level0_row3" class="row_heading level0 row3" >sales</th>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row3_col0" class="data row3 col0" >0.782224</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row3_col1" class="data row3 col1" >0.576223</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row3_col2" class="data row3 col2" >0.228299</td>
#         <td id="T_b5b8835a_fa8d_11e8_88f4_a8667f12a7a1row3_col3" class="data row3 col3" >1</td>
#     </tr></tbody>
# </table>

# %%
#Question: my_df.corr()
sns.heatmap(data.corr(),vmin=-1,vmax=1)

# %%
sns.pairplot(data[['radio','newspaper']]);

# %%
#Question: Casuality test 
# DAG model

# %%
X=np.random.randn(100)
Y=5+2*X+np.random.randn(100)
dag=pd.DataFrame({'X':X,'Y':Y})
sns.pairplot(dag);

# %%
Y=np.random.randn(100)
X=5+2*Y+np.random.randn(100)
dag=pd.DataFrame({'X':X,'Y':Y})
sns.pairplot(dag);

# %%
X=np.random.randn(100)
Y=5+np.random.randn(100)
dag=pd.DataFrame({'X':X,'Y':Y})
sns.pairplot(dag);

# %%
X=5+np.random.randn(100)
Z=X+0.1*np.random.randn(100)
Y=3+Z+np.random.randn(100)
dag=pd.DataFrame({'X':X,'Y':Y,'Z':Z})
sns.pairplot(dag);

# %%
Z=np.random.randn(100)
X=5+2*Z+np.random.randn(100)
Y=3+3*Z+np.random.randn(100)
common_cause=pd.DataFrame({'X':X,'Y':Y,'Z':Z})
sns.pairplot(common_cause);

# %%
X=5+np.random.randn(100)
Y=3+np.random.randn(100)
Z=X+Y+0.1*np.random.randn(100)
common_effect=pd.DataFrame({'X':X,'Y':Y,'Z':Z})
sns.pairplot(common_effect);
sns.pairplot(common_effect[np.logical_and((7<common_effect['Z']),(common_effect['Z']<8))])

# %%
fig,axs=plt.subplots(1,3,sharey=True)
data.plot(kind='scatter',x='TV',y='sales',ax=axs[0]);
data.plot(kind='scatter',x='radio',y='sales',ax=axs[1]);
data.plot(kind='scatter',x='newspaper',y='sales',ax=axs[2]);
